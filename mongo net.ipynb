# %%
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

client = MongoClient('mongodb+srv://Dustin:admin123456@cluster0.akozd.mongodb.net/test')
#db.create_collection("clasemongodb")
db = client["clasemongodb"]

listas= db.listas

import numpy as np
import random

print("LISTADO DE CIUDADANOS")
nombres=["Luis","Miguel","Kevin","Dustin","Paula","Steven","Paul","Jorge","Ricardo","Eduardo"]
apellidos=["Muzo","Chavez","Pinanjota","Perez","Zambrano","Zaldumbide","Guaniuna","Espinoza","Escobar","Monteros"]


k=int(input("INGRESE N CIUDADANOS"))

for i in range(k):
    a = np.random.randint(low=1, high=1000000009, size=1).tolist()
    
    edad = np.random.randint(low=18, high=80, size=1).tolist()

    

    nom_C=[]
    ape_C=[]
    
    
    for i in range (2):
        n=np.random.randint(0,9)
        nom_C.append(nombres[n])

    print(nom_C)
    
    


    for i in range (2):
        n=np.random.randint(0,9)
        ape_C.append(apellidos[n])
        
    print(ape_C)
    print(edad)
    
    p=a[0]*9
    print(p)

    
    print("--------------------------------------------------------------------------------")
    
    
    script=[{'Nombres_Completos':nom_C,'Apellidos_Completos':ape_C,'Edad:':edad,'Cedula:':p}]
    
    listas.insert_many(script)
    
cursor = db.listas.find({})
for doc in cursor:
    print(doc)
# Out:
# LISTADO DE CIUDADANOS
# INGRESE N CIUDADANOS5
# ['Jorge', 'Ricardo']
# ['Chavez', 'Zambrano']
# [36]
# 6861954996
# --------------------------------------------------------------------------------
# ['Paula', 'Steven']
# ['Zambrano', 'Zambrano']
# [57]
# 2657439315
# --------------------------------------------------------------------------------
# ['Luis', 'Jorge']
# ['Zambrano', 'Perez']
# [57]
# 5932110933
# --------------------------------------------------------------------------------
# ['Paul', 'Ricardo']
# ['Zaldumbide', 'Escobar']
# [28]
# 6673575681
# --------------------------------------------------------------------------------
# ['Paula', 'Dustin']
# ['Chavez', 'Zaldumbide']
# [56]
# 8067250143
# --------------------------------------------------------------------------------
# {'_id': ObjectId('61e8b245e564552b70edbc7e'), 'Nombres_Completos': ['Kevin', 'Paul'], 'Apellidos_Completos': ['Escobar', 'Muzo'], 'Edad:': [18], 'Cedula:': 8071938126}
# {'_id': ObjectId('61e8b246e564552b70edbc7f'), 'Nombres_Completos': ['Jorge', 'Jorge'], 'Apellidos_Completos': ['Pinanjota', 'Escobar'], 'Edad:': [46], 'Cedula:': 226437705}
# {'_id': ObjectId('61e8b246e564552b70edbc80'), 'Nombres_Completos': ['Kevin', 'Miguel'], 'Apellidos_Completos': ['Pinanjota', 'Zambrano'], 'Edad:': [31], 'Cedula:': 8534920365}
# {'_id': ObjectId('61e8b66be564552b70edbc82'), 'Nombres_Completos': ['Jorge', 'Ricardo'], 'Apellidos_Completos': ['Chavez', 'Zambrano'], 'Edad:': [36], 'Cedula:': 6861954996}
# {'_id': ObjectId('61e8b66ce564552b70edbc83'), 'Nombres_Completos': ['Paula', 'Steven'], 'Apellidos_Completos': ['Zambrano', 'Zambrano'], 'Edad:': [57], 'Cedula:': 2657439315}
# {'_id': ObjectId('61e8b66ce564552b70edbc84'), 'Nombres_Completos': ['Luis', 'Jorge'], 'Apellidos_Completos': ['Zambrano', 'Perez'], 'Edad:': [57], 'Cedula:': 5932110933}
# {'_id': ObjectId('61e8b66ce564552b70edbc85'), 'Nombres_Completos': ['Paul', 'Ricardo'], 'Apellidos_Completos': ['Zaldumbide', 'Escobar'], 'Edad:': [28], 'Cedula:': 6673575681}
# {'_id': ObjectId('61e8b66ce564552b70edbc86'), 'Nombres_Completos': ['Paula', 'Dustin'], 'Apellidos_Completos': ['Chavez', 'Zaldumbide'], 'Edad:': [56], 'Cedula:': 8067250143}
