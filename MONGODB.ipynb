# %%
#Dustin Chávez 

import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

client = MongoClient('localhost',27017)
#db.create_collection("clasemongodb")
db = client["clasemongodb"]

listas= db.listas

import numpy as np
import random

print("LISTADO DE CIUDADANOS")
nombres=["Luis","Miguel","Kevin","Dustin","Paula","Steven","Paul","Jorge","Ricardo","Eduardo"]
apellidos=["Muzo","Chavez","Pinanjota","Perez","Zambrano","Zaldumbide","Guaniuna","Espinoza","Escobar","Monteros"]


k=int(input("INGRESE N CIUDADANOS"))

for i in range(k):
    a = np.random.randint(low=1, high=1000000009, size=1).tolist()
    
    edad = np.random.randint(low=18, high=80, size=1).tolist()

    

    nom_C=[]
    ape_C=[]
    
    
    for i in range (2):
        n=np.random.randint(0,9)
        nom_C.append(nombres[n])

    print(nom_C)
    
    


    for i in range (2):
        n=np.random.randint(0,9)
        ape_C.append(apellidos[n])
        
    print(ape_C)
    print(edad)
    
    p=a[0]*9
    print(p)

    
    print("--------------------------------------------------------------------------------")
    
    
    script=[{'Nombres_Completos':nom_C,'Apellidos_Completos':ape_C,'Edad:':edad,'Cedula:':p}]
    
    listas.insert_many(script)

print("************************************************************************************")
print("Crear una función que muestre los elementos ingresados en la base de datos.")
cursor = db.listas.find({})
for doc in cursor:
    print(doc)
# Out:
# LISTADO DE CIUDADANOS
# INGRESE N CIUDADANOS5
# ['Jorge', 'Steven']
# ['Chavez', 'Perez']
# [77]
# 4850324370
# --------------------------------------------------------------------------------
# ['Dustin', 'Luis']
# ['Chavez', 'Espinoza']
# [73]
# 8976820122
# --------------------------------------------------------------------------------
# ['Luis', 'Luis']
# ['Chavez', 'Perez']
# [28]
# 6817752873
# --------------------------------------------------------------------------------
# ['Dustin', 'Paula']
# ['Zambrano', 'Pinanjota']
# [51]
# 3969537300
# --------------------------------------------------------------------------------
# ['Jorge', 'Jorge']
# ['Chavez', 'Espinoza']
# [57]
# 8344128429
# --------------------------------------------------------------------------------
# ************************************************************************************
# Crear una función que muestre los elementos ingresados en la base de datos.
# {'_id': ObjectId('61e8aac99a96accf4de8316a'), 'Nombres_Completos': ['Jorge', 'Steven'], 'Apellidos_Completos': ['Chavez', 'Perez'], 'Edad:': [77], 'Cedula:': 4850324370}
# {'_id': ObjectId('61e8aac99a96accf4de8316b'), 'Nombres_Completos': ['Dustin', 'Luis'], 'Apellidos_Completos': ['Chavez', 'Espinoza'], 'Edad:': [73], 'Cedula:': 8976820122}
# {'_id': ObjectId('61e8aac99a96accf4de8316c'), 'Nombres_Completos': ['Luis', 'Luis'], 'Apellidos_Completos': ['Chavez', 'Perez'], 'Edad:': [28], 'Cedula:': 6817752873}
# {'_id': ObjectId('61e8aac99a96accf4de8316d'), 'Nombres_Completos': ['Dustin', 'Paula'], 'Apellidos_Completos': ['Zambrano', 'Pinanjota'], 'Edad:': [51], 'Cedula:': 3969537300}
# {'_id': ObjectId('61e8aac99a96accf4de8316e'), 'Nombres_Completos': ['Jorge', 'Jorge'], 'Apellidos_Completos': ['Chavez', 'Espinoza'], 'Edad:': [57], 'Cedula:': 8344128429}

# %%
db.create_collection("listas")
